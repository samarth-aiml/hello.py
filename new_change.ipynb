# %% [markdown]
# <a href="https://colab.research.google.com/github/samarth-aiml/learning.py/blob/main/new_change.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello world') # print fuction
print("i am samarth.i like food")
print(type(679)) # type function for telling data type.
print(type(True))
print(type("string"))
print(type(485.6))
# Out:
# hello world
# i am samarth.i like food
# <class 'int'>
# <class 'bool'>
# <class 'str'>
# <class 'float'>

# %%
#arithmetic operations
x = float(input("enter your number here:"))  #numbers comparing formula for catching mistakes
y = float(input("enter your number here:"))
formula = x>=y
print("your number is:",formula)
# Out:
# enter your number here:99999999999
# enter your number here:99999999999
# your number is: True

# %%
name = str(input("what is your name?"))
age = int(input('what is your age?'))
print("my age is =",age)
print("youre getting cooked",name)
# Out:
# what is your name?samarth
# what is your age?18
# my age is = 18
# youre getting cooked samarth

# %%
# Out:
# --- Celsius to Fahrenheit Converter ---
# Enter temperature in Celsius: 100
# 100.0°C is equal to 212.0°F
# -------------------------------------
# Project complete! Try running it with different temperatures.

# %%
# Simple Miles to Kilometers Converter Project

print("--- Miles to Kilometers Converter ---")

miles = floa

# %%
# Simple Miles to Kilometers Converter Project

print("--- Miles to Kilometers Converter ---")

# 1. Get input from the user for the distance in miles with error handling
while True:
    try:
        miles_str = input("Enter distance in miles: ")
        miles = float(miles_str)
        break # Exit loop if input is valid
    except ValueError:
        print("Invalid input. Please enter a numerical value for miles.")

# 2. Perform the conversion calculation
# 1 mile is approximately 1.60934 kilometers
kilometers = miles * 1.60934

# 3. Display the result using the .format() method (no f-strings)
print("{} miles is equal to {} kilometers.".format(miles, kilometers))

print("----------------------------------------")
print("Project complete! Run it with different distances.")
# Out:
# --- Miles to Kilometers Converter ---
# Enter distance in miles: 60
# 60.0 miles is equal to 96.5604 kilometers.
# ----------------------------------------
# Project complete! Run it with different distances.
